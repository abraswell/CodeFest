# %%
import pandas as pd
import geopandas as gpd
import os, sys
import numpy as np
from matplotlib import pyplot as plt

# %%
## look at hurrican wilma

# %%
# slosh = 'SLOSH_Innundation_Data/Inundation_polygons/Polygon_Cat1_outline.shp'
# gdf = gpd.read_file(slosh)
# gdf.plot()

# %%
# neighborhood csv... join regionID from neighborhood polygons to medianHousePricePerSqFt csv file
#neigh_shp = 'Neighborhoods/Neighborhood_polygons/PanhandleFl_Neigh_proj.shp'
zillow_csv = 'C:/Users/anbr4034/Dropbox/Repositories/CodeFest/Data/Zillow_Data/Structures/Structures/PanFl_Structures.csv'
neigh_shp = 'C:/Users/anbr4034/Dropbox/Repositories/CodeFest/Data/Neighborhoods/PanFl_Neigh_WithDistance.shp'

neigh_df = gpd.read_file(neigh_shp)
zillow_df = pd.read_csv(zillow_csv)

# %%
neigh_df.head()
# Out:
#   State      County              City        Name RegionID  NEAR_FID  \
# 0    FL      Orange           Orlando     Alafaya    15046     33846
# 1    FL     Broward         Hollywood   Hillcrest    25125     34917
# 2    FL  Miami-Dade             Miami    Brickell    55477     34997
# 3    FL       Pasco   New Port Richey  North Park   116942      5201
# 4    FL     Volusia  New Smyrna Beach  South West   121790     33325
#
#       NEAR_DIST                                           geometry
# 0  20353.791610  POLYGON ((1455291.559658508 714284.254792735, ...
# 1   4363.193135  POLYGON ((1589487.493421007 459691.2616779506,...
# 2      0.000000  POLYGON ((1593401.634173049 435138.7320546452,...
# 3    488.849583  POLYGON ((1303881.935526199 667939.7120311093,...
# 4    286.567972  POLYGON ((1463240.95545853 776744.8219052199, ...

# %%
zillow_df.head()
zillow_df["YearBuilt"].unique()
# Out:
# array([   0, 1959, 1979, 1957, 1956, 1955, 1974, 1925, 1960, 1978, 1981,
#        1954, 1958, 1971, 1962, 1982, 1967, 1986, 1961, 2004, 1977, 2007,
#        1980, 1968, 2002, 2014, 1953, 1969, 1950, 2010, 1987, 1985, 1983,
#        2009, 1973, 2006, 1975, 1970, 1964, 1948, 1972, 1949, 1991, 1951,
#        1952, 1963, 1990, 1989, 1965, 1920, 1988, 1947, 1976, 1945, 1984,
#        1994, 1966, 1940, 1992, 1946, 2000, 2013, 1998, 1997, 1995, 2005,
#        1993, 1915, 2001, 1926, 1938, 1927, 1941, 1928, 1996, 1922, 1924,
#        1930, 1935, 2008, 1939, 1923, 1936, 1999, 1910, 1916, 2011, 2003,
#        1942, 1918, 1921, 1888, 1932, 1937, 2012, 1929, 1905, 1919, 1934,
#        1900, 1944, 1901, 1913, 1933, 1931, 1943, 1912, 1914, 1917,    8,
#        1903, 1904, 1906, 1911, 1902, 2015], dtype=int64)

# %%
## see how many regionIDs are in neigh_df
neigh_df['RegionID'].unique().shape
# Out:
# (1050,)

# %%
# # join zillow_df to neigh_df by RegionID

# # help(neigh_df.join)
# join_df = neigh_df.join(zillow_df, on='RegionID', how='left', lsuffix='_nbrhd')

# %%
neigh_df['RegionID'].dtype, zillow_df['RegionID'].dtype
# Out:
# (dtype('O'), dtype('int64'))

# %%
## the data type of RegionID is Object for neighborhood, and Int64. need to change data type of RegionID column in neigh
neigh_df[['RegionID']] = neigh_df[['RegionID']].apply(pd.to_numeric)
zillow_df[['YearBuilt']] = zillow_df[['YearBuilt']].apply(pd.to_numeric)
# neigh_df[['RegionID']] = neigh_df[['RegionID']].astype('int64') # this would explicitly change it to int64
neigh_df['RegionID'].dtype
zillow_df['YearBuilt'].dtype
# Out:
# dtype('int64')

# %%
## now we can join the dataframes by RegionID by using pd.merge
join_df = neigh_df.merge(zillow_df, on='RegionID') # , how='outer', lsuffix='_nbrhd')
join_df.shape, neigh_df.shape, zillow_df.shape
# Out:
# ((7765, 11), (1050, 8), (7765, 4))

# %%
join_df.shape, neigh_df.shape, zillow_df.shape
# Out:
# ((7765, 11), (1050, 8), (7765, 4))

# %%
join_df['RegionID'].hist()

# %%
common_ids = list(set(neigh_df['RegionID']).intersection(zillow_df['RegionID']))
len(common_ids)
# Out:
# 1035

# %%
region_id_groups_nonan = join_df.dropna().groupby('RegionID')

# %%
join_df = join_df.dropna()

# %%
join_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 7765 entries, 0 to 7764
# Data columns (total 11 columns):
# State              7765 non-null object
# County             7765 non-null object
# City               7765 non-null object
# Name               7765 non-null object
# RegionID           7765 non-null int64
# NEAR_FID           7765 non-null int64
# NEAR_DIST          7765 non-null float64
# geometry           7765 non-null object
# Unnamed: 0         7765 non-null int64
# YearBuilt          7765 non-null int64
# CountStructures    7765 non-null int64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 576.3+ KB

# %%
for i,col in enumerate(join_df.columns):
    print(i, col)
# Out:
# 0 State
# 1 County
# 2 City
# 3 Name
# 4 RegionID
# 5 NEAR_FID
# 6 NEAR_DIST
# 7 geometry
# 8 Unnamed: 0
# 9 YearBuilt
# 10 CountStructures

# %%
join_df[join_df.columns[14:]].shape
# Out:
# (7765, 0)

# %%
## subset by a city name
# city_df = join_df.loc[join_df['City_x'] == 'Naples']
# city_df.shape
join_df.head()
city_df = join_df.loc[join_df['City'] == 'New Port Richey']
city_df.shape
# Out:
# (948, 11)

# %%
city_df.head()
# Out:
#    State County             City        Name  RegionID  NEAR_FID   NEAR_DIST  \
# 6     FL  Pasco  New Port Richey  North Park    116942      5201  488.849583
# 7     FL  Pasco  New Port Richey  North Park    116942      5201  488.849583
# 8     FL  Pasco  New Port Richey  North Park    116942      5201  488.849583
# 9     FL  Pasco  New Port Richey  North Park    116942      5201  488.849583
# 10    FL  Pasco  New Port Richey  North Park    116942      5201  488.849583
#
#                                              geometry  Unnamed: 0  YearBuilt  \
# 6   POLYGON ((1303881.935526199 667939.7120311093,...         824       2004
# 7   POLYGON ((1303881.935526199 667939.7120311093,...         879       1986
# 8   POLYGON ((1303881.935526199 667939.7120311093,...         940       1984
# 9   POLYGON ((1303881.935526199 667939.7120311093,...        1027       2013
# 10  POLYGON ((1303881.935526199 667939.7120311093,...        1213       1973
#
#     CountStructures
# 6                80
# 7                70
# 8                57
# 9                47
# 10               31

# %%
city_df
city_df.head()
city_df["YearBuilt"].unique()
# Out:
# array([2004, 1986, 1984, 2013, 1973, 1958,    0, 1981, 1965, 2007, 1960,
#        1980, 1987, 1977, 1966, 1985, 1964, 1967, 1959, 1962, 1963, 1971,
#        1972, 1982, 1983, 1989, 1956, 1961, 1968, 1955, 1957, 1979, 2002,
#        1950, 1996, 1969, 1970, 1988, 1946, 1976, 2000, 2008, 1953, 1954,
#        1978, 1995, 1925, 1949, 1951, 1974, 1997, 1999, 2003, 1952, 1945,
#        1948, 1926, 1930, 1924, 1936, 1940, 1920, 1942, 1975, 1991, 2010,
#        2014, 1916, 1922, 1921, 1935, 1938, 2006, 1998, 1927, 1944, 1990,
#        2005, 2009, 1915, 1918, 1923, 1931, 1932, 1937, 1994, 2001, 1917,
#        1928, 1941, 1993, 2011, 2012, 1992, 1933, 1947, 1912, 1929, 1939],
#       dtype=int64)

# %%
city_df.head()
city_df["Name"].unique()
# Out:
# array(['North Park', 'Big Bend', 'Downtown', 'Southeast', 'Northeast',
#        'Northwest', 'Southwest', 'Jasmine Hills', 'Le Clair',
#        'The Heights', 'North River', 'South River', 'Sims Grant',
#        'West Grand', 'East Grand', 'East Madison', 'Lake Estates',
#        'Schwettman Oaks'], dtype=object)

# %%
city_df_grouped = city_df.groupby('YearBuilt').count()

# %%
city_df_grouped
# Out:
#            State  County  City  Name  RegionID  NEAR_FID  NEAR_DIST  geometry  \
# YearBuilt
# 0             17      17    17    17        17        17         17        17
# 1912           1       1     1     1         1         1          1         1
# 1915           2       2     2     2         2         2          2         2
# 1916           4       4     4     4         4         4          4         4
# 1917           1       1     1     1         1         1          1         1
# 1918           2       2     2     2         2         2          2         2
# 1920           4       4     4     4         4         4          4         4
# 1921           2       2     2     2         2         2          2         2
# 1922           2       2     2     2         2         2          2         2
# 1923           2       2     2     2         2         2          2         2
# 1924           1       1     1     1         1         1          1         1
# 1925           8       8     8     8         8         8          8         8
# 1926           6       6     6     6         6         6          6         6
# 1927           2       2     2     2         2         2          2         2
# 1928           3       3     3     3         3         3          3         3
# 1929           1       1     1     1         1         1          1         1
# 1930           6       6     6     6         6         6          6         6
# 1931           2       2     2     2         2         2          2         2
# 1932           3       3     3     3         3         3          3         3
# 1933           1       1     1     1         1         1          1         1
# 1935           6       6     6     6         6         6          6         6
# 1936          10      10    10    10        10        10         10        10
# 1937           2       2     2     2         2         2          2         2
# 1938           5       5     5     5         5         5          5         5
# 1939           1       1     1     1         1         1          1         1
# 1940           9       9     9     9         9         9          9         9
# 1941           3       3     3     3         3         3          3         3
# 1942           2       2     2     2         2         2          2         2
# 1944           3       3     3     3         3         3          3         3
# 1945           8       8     8     8         8         8          8         8
# ...          ...     ...   ...   ...       ...       ...        ...       ...
# 1985          16      16    16    16        16        16         16        16
# 1986          16      16    16    16        16        16         16        16
# 1987          16      16    16    16        16        16         16        16
# 1988          17      17    17    17        17        17         17        17
# 1989          11      11    11    11        11        11         11        11
# 1990          12      12    12    12        12        12         12        12
# 1991          10      10    10    10        10        10         10        10
# 1992           8       8     8     8         8         8          8         8
# 1993           9       9     9     9         9         9          9         9
# 1994          10      10    10    10        10        10         10        10
# 1995          12      12    12    12        12        12         12        12
# 1996          10      10    10    10        10        10         10        10
# 1997           9       9     9     9         9         9          9         9
# 1998          12      12    12    12        12        12         12        12
# 1999          12      12    12    12        12        12         12        12
# 2000           9       9     9     9         9         9          9         9
# 2001           9       9     9     9         9         9          9         9
# 2002          13      13    13    13        13        13         13        13
# 2003          14      14    14    14        14        14         14        14
# 2004          16      16    16    16        16        16         16        16
# 2005          13      13    13    13        13        13         13        13
# 2006          14      14    14    14        14        14         14        14
# 2007          10      10    10    10        10        10         10        10
# 2008          12      12    12    12        12        12         12        12
# 2009           5       5     5     5         5         5          5         5
# 2010           7       7     7     7         7         7          7         7
# 2011           5       5     5     5         5         5          5         5
# 2012           6       6     6     6         6         6          6         6
# 2013           5       5     5     5         5         5          5         5
# 2014          10      10    10    10        10        10         10        10
#
#            Unnamed: 0  CountStructures
# YearBuilt
# 0                  17               17
# 1912                1                1
# 1915                2                2
# 1916                4                4
# 1917                1                1
# 1918                2                2
# 1920                4                4
# 1921                2                2
# 1922                2                2
# 1923                2                2
# 1924                1                1
# 1925                8                8
# 1926                6                6
# 1927                2                2
# 1928                3                3
# 1929                1                1
# 1930                6                6
# 1931                2                2
# 1932                3                3
# 1933                1                1
# 1935                6                6
# 1936               10               10
# 1937                2                2
# 1938                5                5
# 1939                1                1
# 1940                9                9
# 1941                3                3
# 1942                2                2
# 1944                3                3
# 1945                8                8
# ...               ...              ...
# 1985               16               16
# 1986               16               16
# 1987               16               16
# 1988               17               17
# 1989               11               11
# 1990               12               12
# 1991               10               10
# 1992                8                8
# 1993                9                9
# 1994               10               10
# 1995               12               12
# 1996               10               10
# 1997                9                9
# 1998               12               12
# 1999               12               12
# 2000                9                9
# 2001                9                9
# 2002               13               13
# 2003               14               14
# 2004               16               16
# 2005               13               13
# 2006               14               14
# 2007               10               10
# 2008               12               12
# 2009                5                5
# 2010                7                7
# 2011                5                5
# 2012                6                6
# 2013                5                5
# 2014               10               10
#
# [99 rows x 10 columns]

# %%
#city_df.groupby("Name", "YearBuilt")["CountStructures"].sum()
fig, ax = plt.subplots()
city_df.groupby('Name', 'YearBuilt').count().plot(x='YearBuilt', y= 'CountStructures', ax=ax, legend = True)
#city_df.plot(x=city_df.YearBuilt, y= city_df.CountStructures) # ax=ax, legend = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-04618d7d7572> in <module>()
#       1 #city_df.groupby("Name", "YearBuilt")["CountStructures"].sum()
#       2 fig, ax = plt.subplots()
# ----> 3 city_df.groupby('Name', 'YearBuilt').count().plot(x='YearBuilt', y= 'CountStructures', ax=ax, legend = True)
#       4 #city_df.plot(x=city_df.YearBuilt, y= city_df.CountStructures) # ax=ax, legend = True)
#
# ~\Anaconda3\envs\earth-analytics-python\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    5157         if level is None and by is None:
#    5158             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 5159         axis = self._get_axis_number(axis)
#    5160         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    5161                        sort=sort, group_keys=group_keys, squeeze=squeeze,
#
# ~\Anaconda3\envs\earth-analytics-python\lib\site-packages\pandas\core\generic.py in _get_axis_number(self, axis)
#     355                 pass
#     356         raise ValueError('No axis named {0} for object type {1}'
# --> 357                          .format(axis, type(self)))
#     358
#     359     def _get_axis_name(self, axis):
#
# ValueError: No axis named YearBuilt for object type <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
#city_name_df = city_df.set_index('Name')



xtick_ls = list(city_df.columns[-2])
#plot_df = city_name_df[city_name_df.columns[-1]].T
city_df.plot(x= "YearBuilt", y = "CountStructures", figsize=(20,20))#, xticks=xtick_ls)
plt.title('Number of Structures Built')

# %%
city_df.head()

# %%
plot_df.head()

# %%
# make the plot
fig,ax = plt.subplots(figsize=(20,20))
labels = list(city_df.columns[-1])
ax.plot(plot_df, label=labels) # plot the nupy array not the dataframe
#plt.axvline(x='2005-11', color='r', linestyle='--')
plt.title('median home value per sq ft for Naples')
plt.legend()
plt.show()

# %%
list(plot_df.columns)

# %%
# make a plot that has date on x axis
import matplotlib.dates as mdates
import matplotlib.cbook as cbook

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
yearsFmt = mdates.DateFormatter('%Y')


# make the plot
fig,ax = plt.subplots(figsize=(20,20))
ax.plot(plot_df.values[:,0]) # plot the nupy array not the dataframe


# format the ticks
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(yearsFmt)
# ax.xaxis.set_minor_locator(months)

# round to nearest years...
date_list = list(city_name_df.columns[14:].values)
datemin = np.datetime64(date_list[0], 'Y')
datemax = np.datetime64(date_list[-1], 'Y') + np.timedelta64(1, 'Y')
datemax = np.datetime64('2018', 'Y')
temp = ax.set_xlim(datemin, datemax)

ax.format_xdata = mdates.DateFormatter('%Y-%m-%d')
# ax.format_xdata = mdates.DateFormatter('%Y')

# plt.xticks(rotation=70)
# plt.legend()

# rotates and right aligns the x labels, and moves the bottom of the
# axes up to make room for them
fig.autofmt_xdate()

plt.show()

# %%
temp[1] - temp[0]

# %%
years

# %%
plot_df.head()

# %%
plot_df.shape
